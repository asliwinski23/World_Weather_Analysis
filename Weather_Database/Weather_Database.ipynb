# %%
import requests
from datetime import datetime
import numpy as np
from citipy import citipy
import pandas as pd
import matplotlib.pyplot as plt
import time
from scipy.stats import linregress

# %%
from config import weather_api_key

# %%
# print 2000 random lats
lats = np.random.uniform(-90.000, 90.000, 2000)
lngs = np.random.uniform(-180,180,2000)
lat_lngs = list(zip(lats,lngs))

# %%
# Use the tuple() function to display the latitude and longitude combinations.
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in lat_lngs:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
print(len(cities))
# Out:
# 778

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
city = ""
units = "Imperial"
# query_url = f"{url}appid={weather_api_key}&q={city}&units={units}"

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
#     city_url = url + "&q=" + city.replace(" ","+")
    city_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
    print(city_url)
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
# Run an API request for each of the cities.
    try:
# Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=la ronge&units=Imperial
# Processing Record 1 of Set 1 | la ronge
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=barentsburg&units=Imperial
# Processing Record 2 of Set 1 | barentsburg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=albany&units=Imperial
# Processing Record 3 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=rikitea&units=Imperial
# Processing Record 4 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=castro&units=Imperial
# Processing Record 5 of Set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=mar del plata&units=Imperial
# Processing Record 6 of Set 1 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=esperance&units=Imperial
# Processing Record 7 of Set 1 | esperance
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=namatanai&units=Imperial
# Processing Record 8 of Set 1 | namatanai
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=dikson&units=Imperial
# Processing Record 9 of Set 1 | dikson
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=sept-iles&units=Imperial
# Processing Record 10 of Set 1 | sept-iles
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=ribeira grande&units=Imperial
# Processing Record 11 of Set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=panormos&units=Imperial
# Processing Record 12 of Set 1 | panormos
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=nizhneyansk&units=Imperial
# Processing Record 13 of Set 1 | nizhneyansk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=glyadyanskoye&units=Imperial
# Processing Record 14 of Set 1 | glyadyanskoye
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=cape town&units=Imperial
# Processing Record 15 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=verkhnyaya inta&units=Imperial
# Processing Record 16 of Set 1 | verkhnyaya inta
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=general jose eduvigis diaz&units=Imperial
# Processing Record 17 of Set 1 | general jose eduvigis diaz
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=wynyard&units=Imperial
# Processing Record 18 of Set 1 | wynyard
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=illoqqortoormiut&units=Imperial
# Processing Record 19 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=mataura&units=Imperial
# Processing Record 20 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=whitianga&units=Imperial
# Processing Record 21 of Set 1 | whitianga
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=sakakah&units=Imperial
# Processing Record 22 of Set 1 | sakakah
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=saint george&units=Imperial
# Processing Record 23 of Set 1 | saint george
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=bengkulu&units=Imperial
# Processing Record 24 of Set 1 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=biak&units=Imperial
# Processing Record 25 of Set 1 | biak
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=torbay&units=Imperial
# Processing Record 26 of Set 1 | torbay
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=saidpur&units=Imperial
# Processing Record 27 of Set 1 | saidpur
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=norman wells&units=Imperial
# Processing Record 28 of Set 1 | norman wells
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=grand river south east&units=Imperial
# Processing Record 29 of Set 1 | grand river south east
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=korla&units=Imperial
# Processing Record 30 of Set 1 | korla
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=isangel&units=Imperial
# Processing Record 31 of Set 1 | isangel
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=taolanaro&units=Imperial
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=busselton&units=Imperial
# Processing Record 33 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=punta arenas&units=Imperial
# Processing Record 34 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=djambala&units=Imperial
# Processing Record 35 of Set 1 | djambala
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=cabo san lucas&units=Imperial
# Processing Record 36 of Set 1 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=puerto ayora&units=Imperial
# Processing Record 37 of Set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=pitimbu&units=Imperial
# Processing Record 38 of Set 1 | pitimbu
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=nhulunbuy&units=Imperial
# Processing Record 39 of Set 1 | nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=soderhamn&units=Imperial
# Processing Record 40 of Set 1 | soderhamn
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=hobart&units=Imperial
# Processing Record 41 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=tsihombe&units=Imperial
# Processing Record 42 of Set 1 | tsihombe
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=rungata&units=Imperial
# Processing Record 43 of Set 1 | rungata
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=kahului&units=Imperial
# Processing Record 44 of Set 1 | kahului
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=magdalena&units=Imperial
# Processing Record 45 of Set 1 | magdalena
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=nome&units=Imperial
# Processing Record 46 of Set 1 | nome
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=thompson&units=Imperial
# Processing Record 47 of Set 1 | thompson
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=sobolevo&units=Imperial
# Processing Record 48 of Set 1 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=sedelnikovo&units=Imperial
# Processing Record 49 of Set 1 | sedelnikovo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=cabedelo&units=Imperial
# Processing Record 50 of Set 1 | cabedelo
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=tasiilaq&units=Imperial
# Processing Record 1 of Set 2 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=karratha&units=Imperial
# Processing Record 2 of Set 2 | karratha
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=belushya guba&units=Imperial
# Processing Record 3 of Set 2 | belushya guba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=cherskiy&units=Imperial
# Processing Record 4 of Set 2 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=ishinomaki&units=Imperial
# Processing Record 5 of Set 2 | ishinomaki
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=bluff&units=Imperial
# Processing Record 6 of Set 2 | bluff
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=lorengau&units=Imperial
# Processing Record 7 of Set 2 | lorengau
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=linxi&units=Imperial
# Processing Record 8 of Set 2 | linxi
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=yellowknife&units=Imperial
# Processing Record 9 of Set 2 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=hargeysa&units=Imperial
# Processing Record 10 of Set 2 | hargeysa
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=airai&units=Imperial
# Processing Record 11 of Set 2 | airai
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=hithadhoo&units=Imperial
# Processing Record 12 of Set 2 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=baykit&units=Imperial
# Processing Record 13 of Set 2 | baykit
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=jamestown&units=Imperial
# Processing Record 14 of Set 2 | jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=hambantota&units=Imperial
# Processing Record 15 of Set 2 | hambantota
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=east london&units=Imperial
# Processing Record 16 of Set 2 | east london
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=atuona&units=Imperial
# Processing Record 17 of Set 2 | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=bojnurd&units=Imperial
# Processing Record 18 of Set 2 | bojnurd
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=saint-pierre&units=Imperial
# Processing Record 19 of Set 2 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=deputatskiy&units=Imperial
# Processing Record 20 of Set 2 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=klaksvik&units=Imperial
# Processing Record 21 of Set 2 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=ushuaia&units=Imperial
# Processing Record 22 of Set 2 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=ano mera&units=Imperial
# Processing Record 23 of Set 2 | ano mera
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=kapaa&units=Imperial
# Processing Record 24 of Set 2 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=mahebourg&units=Imperial
# Processing Record 25 of Set 2 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=attawapiskat&units=Imperial
# Processing Record 26 of Set 2 | attawapiskat
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=midland&units=Imperial
# Processing Record 27 of Set 2 | midland
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=hermanus&units=Imperial
# Processing Record 28 of Set 2 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=pevek&units=Imperial
# Processing Record 29 of Set 2 | pevek
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=kabo&units=Imperial
# Processing Record 30 of Set 2 | kabo
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=henties bay&units=Imperial
# Processing Record 31 of Set 2 | henties bay
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=payakumbuh&units=Imperial
# Processing Record 32 of Set 2 | payakumbuh
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=pangkalanbuun&units=Imperial
# Processing Record 33 of Set 2 | pangkalanbuun
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=rocha&units=Imperial
# Processing Record 34 of Set 2 | rocha
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=lomovka&units=Imperial
# Processing Record 35 of Set 2 | lomovka
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=martapura&units=Imperial
# Processing Record 36 of Set 2 | martapura
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=tabou&units=Imperial
# Processing Record 37 of Set 2 | tabou
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=hilo&units=Imperial
# Processing Record 38 of Set 2 | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=dossor&units=Imperial
# Processing Record 39 of Set 2 | dossor
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=new norfolk&units=Imperial
# Processing Record 40 of Set 2 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=zemio&units=Imperial
# Processing Record 41 of Set 2 | zemio
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=vaini&units=Imperial
# Processing Record 42 of Set 2 | vaini
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=faro&units=Imperial
# Processing Record 43 of Set 2 | faro
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=port hardy&units=Imperial
# Processing Record 44 of Set 2 | port hardy
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=kraksaan&units=Imperial
# Processing Record 45 of Set 2 | kraksaan
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=victoria&units=Imperial
# Processing Record 46 of Set 2 | victoria
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=mehamn&units=Imperial
# Processing Record 47 of Set 2 | mehamn
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=dudinka&units=Imperial
# Processing Record 48 of Set 2 | dudinka
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=porto novo&units=Imperial
# Processing Record 49 of Set 2 | porto novo
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=saldanha&units=Imperial
# Processing Record 50 of Set 2 | saldanha
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=kaseda&units=Imperial
# Processing Record 1 of Set 3 | kaseda
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=kharan&units=Imperial
# Processing Record 2 of Set 3 | kharan
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=carnarvon&units=Imperial
# Processing Record 3 of Set 3 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=upernavik&units=Imperial
# Processing Record 4 of Set 3 | upernavik
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=malakal&units=Imperial
# Processing Record 5 of Set 3 | malakal
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=umm lajj&units=Imperial
# Processing Record 6 of Set 3 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=katsuura&units=Imperial
# Processing Record 7 of Set 3 | katsuura
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=alotau&units=Imperial
# Processing Record 8 of Set 3 | alotau
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=guerrero negro&units=Imperial
# Processing Record 9 of Set 3 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=xai-xai&units=Imperial
# Processing Record 10 of Set 3 | xai-xai
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=chiredzi&units=Imperial
# Processing Record 11 of Set 3 | chiredzi
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=avarua&units=Imperial
# Processing Record 12 of Set 3 | avarua
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=qui nhon&units=Imperial
# Processing Record 13 of Set 3 | qui nhon
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=bethel&units=Imperial
# Processing Record 14 of Set 3 | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=palabuhanratu&units=Imperial
# Processing Record 15 of Set 3 | palabuhanratu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=pisco&units=Imperial
# Processing Record 16 of Set 3 | pisco
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=clyde river&units=Imperial
# Processing Record 17 of Set 3 | clyde river
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=okhotsk&units=Imperial
# Processing Record 18 of Set 3 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=butaritari&units=Imperial
# Processing Record 19 of Set 3 | butaritari
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=mbanza-ngungu&units=Imperial
# Processing Record 20 of Set 3 | mbanza-ngungu
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=tufanganj&units=Imperial
# Processing Record 21 of Set 3 | tufanganj
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=mitsamiouli&units=Imperial
# Processing Record 22 of Set 3 | mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=bredasdorp&units=Imperial
# Processing Record 23 of Set 3 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=barrow&units=Imperial
# Processing Record 24 of Set 3 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=port hedland&units=Imperial
# Processing Record 25 of Set 3 | port hedland
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=rio grande&units=Imperial
# Processing Record 26 of Set 3 | rio grande
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=souillac&units=Imperial
# Processing Record 27 of Set 3 | souillac
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=santa maria&units=Imperial
# Processing Record 28 of Set 3 | santa maria
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=cherdyn&units=Imperial
# Processing Record 29 of Set 3 | cherdyn
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=tuktoyaktuk&units=Imperial
# Processing Record 30 of Set 3 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=labuhan&units=Imperial
# Processing Record 31 of Set 3 | labuhan
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=ponta delgada&units=Imperial
# Processing Record 32 of Set 3 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=lebu&units=Imperial
# Processing Record 33 of Set 3 | lebu
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=itoman&units=Imperial
# Processing Record 34 of Set 3 | itoman
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=coahuayana&units=Imperial
# Processing Record 35 of Set 3 | coahuayana
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=birin&units=Imperial
# Processing Record 36 of Set 3 | birin
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=barra do garcas&units=Imperial
# Processing Record 37 of Set 3 | barra do garcas
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=ambilobe&units=Imperial
# Processing Record 38 of Set 3 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=vaitupu&units=Imperial
# Processing Record 39 of Set 3 | vaitupu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=petropavlovsk-kamchatskiy&units=Imperial
# Processing Record 40 of Set 3 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=kaitangata&units=Imperial
# Processing Record 41 of Set 3 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=chokurdakh&units=Imperial
# Processing Record 42 of Set 3 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=dehra dun&units=Imperial
# Processing Record 43 of Set 3 | dehra dun
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=tukums&units=Imperial
# Processing Record 44 of Set 3 | tukums
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=arraial do cabo&units=Imperial
# Processing Record 45 of Set 3 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=wiang sa&units=Imperial
# Processing Record 46 of Set 3 | wiang sa
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=cockburn town&units=Imperial
# Processing Record 47 of Set 3 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=amderma&units=Imperial
# Processing Record 48 of Set 3 | amderma
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=ariogala&units=Imperial
# Processing Record 49 of Set 3 | ariogala
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=kavieng&units=Imperial
# Processing Record 50 of Set 3 | kavieng
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=troitsko-pechorsk&units=Imperial
# Processing Record 1 of Set 4 | troitsko-pechorsk
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=asau&units=Imperial
# Processing Record 2 of Set 4 | asau
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=mount gambier&units=Imperial
# Processing Record 3 of Set 4 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=trujillo&units=Imperial
# Processing Record 4 of Set 4 | trujillo
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=bathsheba&units=Imperial
# Processing Record 5 of Set 4 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=honiara&units=Imperial
# Processing Record 6 of Set 4 | honiara
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=cotonou&units=Imperial
# Processing Record 7 of Set 4 | cotonou
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=angoche&units=Imperial
# Processing Record 8 of Set 4 | angoche
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=port moresby&units=Imperial
# Processing Record 9 of Set 4 | port moresby
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=narsaq&units=Imperial
# Processing Record 10 of Set 4 | narsaq
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=sao filipe&units=Imperial
# Processing Record 11 of Set 4 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=hutchinson&units=Imperial
# Processing Record 12 of Set 4 | hutchinson
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=lavrentiya&units=Imperial
# Processing Record 13 of Set 4 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=ponta do sol&units=Imperial
# Processing Record 14 of Set 4 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=ha tinh&units=Imperial
# Processing Record 15 of Set 4 | ha tinh
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=georgetown&units=Imperial
# Processing Record 16 of Set 4 | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=saskylakh&units=Imperial
# Processing Record 17 of Set 4 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=beyneu&units=Imperial
# Processing Record 18 of Set 4 | beyneu
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=coihaique&units=Imperial
# Processing Record 19 of Set 4 | coihaique
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=zhicheng&units=Imperial
# Processing Record 20 of Set 4 | zhicheng
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=half moon bay&units=Imperial
# Processing Record 21 of Set 4 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=haines junction&units=Imperial
# Processing Record 22 of Set 4 | haines junction
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=oyama&units=Imperial
# Processing Record 23 of Set 4 | oyama
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=prince rupert&units=Imperial
# Processing Record 24 of Set 4 | prince rupert
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=esna&units=Imperial
# Processing Record 25 of Set 4 | esna
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=sattahip&units=Imperial
# Processing Record 26 of Set 4 | sattahip
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=srednekolymsk&units=Imperial
# Processing Record 27 of Set 4 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=nikolskoye&units=Imperial
# Processing Record 28 of Set 4 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=lufilufi&units=Imperial
# Processing Record 29 of Set 4 | lufilufi
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=werda&units=Imperial
# Processing Record 30 of Set 4 | werda
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=luderitz&units=Imperial
# Processing Record 31 of Set 4 | luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=aksu&units=Imperial
# Processing Record 32 of Set 4 | aksu
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=ushtobe&units=Imperial
# Processing Record 33 of Set 4 | ushtobe
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=alihe&units=Imperial
# Processing Record 34 of Set 4 | alihe
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=cordoba&units=Imperial
# Processing Record 35 of Set 4 | cordoba
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=zhangjiakou&units=Imperial
# Processing Record 36 of Set 4 | zhangjiakou
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=chapais&units=Imperial
# Processing Record 37 of Set 4 | chapais
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=herouville-saint-clair&units=Imperial
# Processing Record 38 of Set 4 | herouville-saint-clair
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=mackay&units=Imperial
# Processing Record 39 of Set 4 | mackay
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=sheltozero&units=Imperial
# Processing Record 40 of Set 4 | sheltozero
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=oktyabrskoye&units=Imperial
# Processing Record 41 of Set 4 | oktyabrskoye
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=jega&units=Imperial
# Processing Record 42 of Set 4 | jega
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=hofn&units=Imperial
# Processing Record 43 of Set 4 | hofn
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=chimbote&units=Imperial
# Processing Record 44 of Set 4 | chimbote
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=louisbourg&units=Imperial
# Processing Record 45 of Set 4 | louisbourg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=pacific grove&units=Imperial
# Processing Record 46 of Set 4 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=abancay&units=Imperial
# Processing Record 47 of Set 4 | abancay
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=mansa&units=Imperial
# Processing Record 48 of Set 4 | mansa
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=bintulu&units=Imperial
# Processing Record 49 of Set 4 | bintulu
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=lompoc&units=Imperial
# Processing Record 50 of Set 4 | lompoc
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=tarudant&units=Imperial
# Processing Record 1 of Set 5 | tarudant
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=san cristobal&units=Imperial
# Processing Record 2 of Set 5 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=bara&units=Imperial
# Processing Record 3 of Set 5 | bara
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=guiratinga&units=Imperial
# Processing Record 4 of Set 5 | guiratinga
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=sampit&units=Imperial
# Processing Record 5 of Set 5 | sampit
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=khatanga&units=Imperial
# Processing Record 6 of Set 5 | khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=skiros&units=Imperial
# Processing Record 7 of Set 5 | skiros
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=ballina&units=Imperial
# Processing Record 8 of Set 5 | ballina
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=catamarca&units=Imperial
# Processing Record 9 of Set 5 | catamarca
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=urdzhar&units=Imperial
# Processing Record 10 of Set 5 | urdzhar
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=college&units=Imperial
# Processing Record 11 of Set 5 | college
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=helena&units=Imperial
# Processing Record 12 of Set 5 | helena
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=salinopolis&units=Imperial
# Processing Record 13 of Set 5 | salinopolis
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=levelland&units=Imperial
# Processing Record 14 of Set 5 | levelland
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=kidal&units=Imperial
# Processing Record 15 of Set 5 | kidal
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=harper&units=Imperial
# Processing Record 16 of Set 5 | harper
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=homer&units=Imperial
# Processing Record 17 of Set 5 | homer
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=chuy&units=Imperial
# Processing Record 18 of Set 5 | chuy
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=yeppoon&units=Imperial
# Processing Record 19 of Set 5 | yeppoon
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=te anau&units=Imperial
# Processing Record 20 of Set 5 | te anau
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=pietarsaari&units=Imperial
# Processing Record 21 of Set 5 | pietarsaari
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=kralendijk&units=Imperial
# Processing Record 22 of Set 5 | kralendijk
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=hongjiang&units=Imperial
# Processing Record 23 of Set 5 | hongjiang
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=praia da vitoria&units=Imperial
# Processing Record 24 of Set 5 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=tingi&units=Imperial
# Processing Record 25 of Set 5 | tingi
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=looc&units=Imperial
# Processing Record 26 of Set 5 | looc
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=qaanaaq&units=Imperial
# Processing Record 27 of Set 5 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=tyup&units=Imperial
# Processing Record 28 of Set 5 | tyup
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=guicheng&units=Imperial
# Processing Record 29 of Set 5 | guicheng
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=boca do acre&units=Imperial
# Processing Record 30 of Set 5 | boca do acre
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=obuasi&units=Imperial
# Processing Record 31 of Set 5 | obuasi
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=acarau&units=Imperial
# Processing Record 32 of Set 5 | acarau
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=tiksi&units=Imperial
# Processing Record 33 of Set 5 | tiksi
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=tuatapere&units=Imperial
# Processing Record 34 of Set 5 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=faanui&units=Imperial
# Processing Record 35 of Set 5 | faanui
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=balabac&units=Imperial
# Processing Record 36 of Set 5 | balabac
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=port alfred&units=Imperial
# Processing Record 37 of Set 5 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=njombe&units=Imperial
# Processing Record 38 of Set 5 | njombe
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=felnac&units=Imperial
# Processing Record 39 of Set 5 | felnac
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=heilbron&units=Imperial
# Processing Record 40 of Set 5 | heilbron
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=ahuimanu&units=Imperial
# Processing Record 41 of Set 5 | ahuimanu
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=kovdor&units=Imperial
# Processing Record 42 of Set 5 | kovdor
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=kachug&units=Imperial
# Processing Record 43 of Set 5 | kachug
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=vila velha&units=Imperial
# Processing Record 44 of Set 5 | vila velha
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=acajutla&units=Imperial
# Processing Record 45 of Set 5 | acajutla
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=bartica&units=Imperial
# Processing Record 46 of Set 5 | bartica
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=ixtapa&units=Imperial
# Processing Record 47 of Set 5 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=hamilton&units=Imperial
# Processing Record 48 of Set 5 | hamilton
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=samarai&units=Imperial
# Processing Record 49 of Set 5 | samarai
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=pousat&units=Imperial
# Processing Record 50 of Set 5 | pousat
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=aswan&units=Imperial
# Processing Record 1 of Set 6 | aswan
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=komsomolskiy&units=Imperial
# Processing Record 2 of Set 6 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=batagay&units=Imperial
# Processing Record 3 of Set 6 | batagay
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=port elizabeth&units=Imperial
# Processing Record 4 of Set 6 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=tautira&units=Imperial
# Processing Record 5 of Set 6 | tautira
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=kelvington&units=Imperial
# Processing Record 6 of Set 6 | kelvington
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=port-cartier&units=Imperial
# Processing Record 7 of Set 6 | port-cartier
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=gat&units=Imperial
# Processing Record 8 of Set 6 | gat
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=vila franca do campo&units=Imperial
# Processing Record 9 of Set 6 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=praia grande&units=Imperial
# Processing Record 10 of Set 6 | praia grande
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=cidreira&units=Imperial
# Processing Record 11 of Set 6 | cidreira
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=constantine&units=Imperial
# Processing Record 12 of Set 6 | constantine
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=vilhena&units=Imperial
# Processing Record 13 of Set 6 | vilhena
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=aripuana&units=Imperial
# Processing Record 14 of Set 6 | aripuana
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=leh&units=Imperial
# Processing Record 15 of Set 6 | leh
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=grand-santi&units=Imperial
# Processing Record 16 of Set 6 | grand-santi
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=mullaitivu&units=Imperial
# Processing Record 17 of Set 6 | mullaitivu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=provideniya&units=Imperial
# Processing Record 18 of Set 6 | provideniya
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=jinxiang&units=Imperial
# Processing Record 19 of Set 6 | jinxiang
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=tumannyy&units=Imperial
# Processing Record 20 of Set 6 | tumannyy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=gamba&units=Imperial
# Processing Record 21 of Set 6 | gamba
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=touros&units=Imperial
# Processing Record 22 of Set 6 | touros
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=lebork&units=Imperial
# Processing Record 23 of Set 6 | lebork
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=saint-ambroise&units=Imperial
# Processing Record 24 of Set 6 | saint-ambroise
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=searcy&units=Imperial
# Processing Record 25 of Set 6 | searcy
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=kavaratti&units=Imperial
# Processing Record 26 of Set 6 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=sentyabrskiy&units=Imperial
# Processing Record 27 of Set 6 | sentyabrskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=grand gaube&units=Imperial
# Processing Record 28 of Set 6 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=avera&units=Imperial
# Processing Record 29 of Set 6 | avera
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=bubaque&units=Imperial
# Processing Record 30 of Set 6 | bubaque
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=marienburg&units=Imperial
# Processing Record 31 of Set 6 | marienburg
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=roros&units=Imperial
# Processing Record 32 of Set 6 | roros
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=utiroa&units=Imperial
# Processing Record 33 of Set 6 | utiroa
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=ancud&units=Imperial
# Processing Record 34 of Set 6 | ancud
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=evensk&units=Imperial
# Processing Record 35 of Set 6 | evensk
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=yagodnoye&units=Imperial
# Processing Record 36 of Set 6 | yagodnoye
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=bruck an der leitha&units=Imperial
# Processing Record 37 of Set 6 | bruck an der leitha
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=longyearbyen&units=Imperial
# Processing Record 38 of Set 6 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=ondjiva&units=Imperial
# Processing Record 39 of Set 6 | ondjiva
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=pahrump&units=Imperial
# Processing Record 40 of Set 6 | pahrump
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=bandarbeyla&units=Imperial
# Processing Record 41 of Set 6 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=bambous virieux&units=Imperial
# Processing Record 42 of Set 6 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=wundanyi&units=Imperial
# Processing Record 43 of Set 6 | wundanyi
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=lasa&units=Imperial
# Processing Record 44 of Set 6 | lasa
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=nouadhibou&units=Imperial
# Processing Record 45 of Set 6 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=thaton&units=Imperial
# Processing Record 46 of Set 6 | thaton
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=bilma&units=Imperial
# Processing Record 47 of Set 6 | bilma
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=sovetskiy&units=Imperial
# Processing Record 48 of Set 6 | sovetskiy
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=yulara&units=Imperial
# Processing Record 49 of Set 6 | yulara
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=marzuq&units=Imperial
# Processing Record 50 of Set 6 | marzuq
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=abalak&units=Imperial
# Processing Record 1 of Set 7 | abalak
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=adrar&units=Imperial
# Processing Record 2 of Set 7 | adrar
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=gladstone&units=Imperial
# Processing Record 3 of Set 7 | gladstone
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=placetas&units=Imperial
# Processing Record 4 of Set 7 | placetas
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=fort nelson&units=Imperial
# Processing Record 5 of Set 7 | fort nelson
# ...
# Processing Record 26 of Set 14 | carmelo
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=yarmouth&units=Imperial
# Processing Record 27 of Set 14 | yarmouth
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=springfield&units=Imperial
# Processing Record 28 of Set 14 | springfield
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=nguiu&units=Imperial
# Processing Record 29 of Set 14 | nguiu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=anshun&units=Imperial
# Processing Record 30 of Set 14 | anshun
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=monterey&units=Imperial
# Processing Record 31 of Set 14 | monterey
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=sitges&units=Imperial
# Processing Record 32 of Set 14 | sitges
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=turukhansk&units=Imperial
# Processing Record 33 of Set 14 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=marshall&units=Imperial
# Processing Record 34 of Set 14 | marshall
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=baruun-urt&units=Imperial
# Processing Record 35 of Set 14 | baruun-urt
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=igarka&units=Imperial
# Processing Record 36 of Set 14 | igarka
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=trincomalee&units=Imperial
# Processing Record 37 of Set 14 | trincomalee
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=fortuna&units=Imperial
# Processing Record 38 of Set 14 | fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=verkhoyansk&units=Imperial
# Processing Record 39 of Set 14 | verkhoyansk
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=pundaguitan&units=Imperial
# Processing Record 40 of Set 14 | pundaguitan
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=camacha&units=Imperial
# Processing Record 41 of Set 14 | camacha
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=galle&units=Imperial
# Processing Record 42 of Set 14 | galle
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=vysha&units=Imperial
# Processing Record 43 of Set 14 | vysha
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=carutapera&units=Imperial
# Processing Record 44 of Set 14 | carutapera
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=maputo&units=Imperial
# Processing Record 45 of Set 14 | maputo
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=rayong&units=Imperial
# Processing Record 46 of Set 14 | rayong
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=hoquiam&units=Imperial
# Processing Record 47 of Set 14 | hoquiam
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=basoko&units=Imperial
# Processing Record 48 of Set 14 | basoko
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=marquard&units=Imperial
# Processing Record 49 of Set 14 | marquard
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=porto belo&units=Imperial
# Processing Record 50 of Set 14 | porto belo
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=canmore&units=Imperial
# Processing Record 1 of Set 15 | canmore
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=isabela&units=Imperial
# Processing Record 2 of Set 15 | isabela
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=vavoua&units=Imperial
# Processing Record 3 of Set 15 | vavoua
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=seoul&units=Imperial
# Processing Record 4 of Set 15 | seoul
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=mokhsogollokh&units=Imperial
# Processing Record 5 of Set 15 | mokhsogollokh
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=muros&units=Imperial
# Processing Record 6 of Set 15 | muros
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=cairo&units=Imperial
# Processing Record 7 of Set 15 | cairo
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=alice springs&units=Imperial
# Processing Record 8 of Set 15 | alice springs
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=seminole&units=Imperial
# Processing Record 9 of Set 15 | seminole
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=puerto madryn&units=Imperial
# Processing Record 10 of Set 15 | puerto madryn
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=konin&units=Imperial
# Processing Record 11 of Set 15 | konin
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=port hawkesbury&units=Imperial
# Processing Record 12 of Set 15 | port hawkesbury
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=ahumada&units=Imperial
# Processing Record 13 of Set 15 | ahumada
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=khorramshahr&units=Imperial
# Processing Record 14 of Set 15 | khorramshahr
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=vao&units=Imperial
# Processing Record 15 of Set 15 | vao
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=bikaner&units=Imperial
# Processing Record 16 of Set 15 | bikaner
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=bridgetown&units=Imperial
# Processing Record 17 of Set 15 | bridgetown
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=abha&units=Imperial
# Processing Record 18 of Set 15 | abha
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=kysyl-syr&units=Imperial
# Processing Record 19 of Set 15 | kysyl-syr
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=jucurutu&units=Imperial
# Processing Record 20 of Set 15 | jucurutu
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=olden&units=Imperial
# Processing Record 21 of Set 15 | olden
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=bilozerka&units=Imperial
# Processing Record 22 of Set 15 | bilozerka
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=los llanos de aridane&units=Imperial
# Processing Record 23 of Set 15 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=quatre cocos&units=Imperial
# Processing Record 24 of Set 15 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=axim&units=Imperial
# Processing Record 25 of Set 15 | axim
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=akyab&units=Imperial
# Processing Record 26 of Set 15 | akyab
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=simbahan&units=Imperial
# Processing Record 27 of Set 15 | simbahan
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=taicheng&units=Imperial
# Processing Record 28 of Set 15 | taicheng
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=lazaro cardenas&units=Imperial
# Processing Record 29 of Set 15 | lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=diamantino&units=Imperial
# Processing Record 30 of Set 15 | diamantino
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=kaiyuan&units=Imperial
# Processing Record 31 of Set 15 | kaiyuan
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=canandaigua&units=Imperial
# Processing Record 32 of Set 15 | canandaigua
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=karaul&units=Imperial
# Processing Record 33 of Set 15 | karaul
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=flinders&units=Imperial
# Processing Record 34 of Set 15 | flinders
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=bogande&units=Imperial
# Processing Record 35 of Set 15 | bogande
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=coquimbo&units=Imperial
# Processing Record 36 of Set 15 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=akdepe&units=Imperial
# Processing Record 37 of Set 15 | akdepe
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=kardamaina&units=Imperial
# Processing Record 38 of Set 15 | kardamaina
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=revelstoke&units=Imperial
# Processing Record 39 of Set 15 | revelstoke
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=matamoros&units=Imperial
# Processing Record 40 of Set 15 | matamoros
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=hammerfest&units=Imperial
# Processing Record 41 of Set 15 | hammerfest
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=jalu&units=Imperial
# Processing Record 42 of Set 15 | jalu
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=solwezi&units=Imperial
# Processing Record 43 of Set 15 | solwezi
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=asilah&units=Imperial
# Processing Record 44 of Set 15 | asilah
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=inuvik&units=Imperial
# Processing Record 45 of Set 15 | inuvik
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=sabzevar&units=Imperial
# Processing Record 46 of Set 15 | sabzevar
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=dzhusaly&units=Imperial
# Processing Record 47 of Set 15 | dzhusaly
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=jiaohe&units=Imperial
# Processing Record 48 of Set 15 | jiaohe
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=clonakilty&units=Imperial
# Processing Record 49 of Set 15 | clonakilty
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=san carlos de bariloche&units=Imperial
# Processing Record 50 of Set 15 | san carlos de bariloche
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=san luis&units=Imperial
# Processing Record 1 of Set 16 | san luis
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=assiniboia&units=Imperial
# Processing Record 2 of Set 16 | assiniboia
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=eruwa&units=Imperial
# Processing Record 3 of Set 16 | eruwa
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=oranjestad&units=Imperial
# Processing Record 4 of Set 16 | oranjestad
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=ola&units=Imperial
# Processing Record 5 of Set 16 | ola
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=lakatoro&units=Imperial
# Processing Record 6 of Set 16 | lakatoro
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=adigeni&units=Imperial
# Processing Record 7 of Set 16 | adigeni
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=koygorodok&units=Imperial
# Processing Record 8 of Set 16 | koygorodok
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=garowe&units=Imperial
# Processing Record 9 of Set 16 | garowe
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=jining&units=Imperial
# Processing Record 10 of Set 16 | jining
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=wuda&units=Imperial
# Processing Record 11 of Set 16 | wuda
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=morehead&units=Imperial
# Processing Record 12 of Set 16 | morehead
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=bacuit&units=Imperial
# Processing Record 13 of Set 16 | bacuit
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=decatur&units=Imperial
# Processing Record 14 of Set 16 | decatur
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=ambon&units=Imperial
# Processing Record 15 of Set 16 | ambon
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=nelson bay&units=Imperial
# Processing Record 16 of Set 16 | nelson bay
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=nenjiang&units=Imperial
# Processing Record 17 of Set 16 | nenjiang
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=tual&units=Imperial
# Processing Record 18 of Set 16 | tual
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=portland&units=Imperial
# Processing Record 19 of Set 16 | portland
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=windhoek&units=Imperial
# Processing Record 20 of Set 16 | windhoek
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=buzuluk&units=Imperial
# Processing Record 21 of Set 16 | buzuluk
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=albion&units=Imperial
# Processing Record 22 of Set 16 | albion
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=baoning&units=Imperial
# Processing Record 23 of Set 16 | baoning
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=roald&units=Imperial
# Processing Record 24 of Set 16 | roald
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=tamandare&units=Imperial
# Processing Record 25 of Set 16 | tamandare
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=kolondieba&units=Imperial
# Processing Record 26 of Set 16 | kolondieba
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=bac lieu&units=Imperial
# Processing Record 27 of Set 16 | bac lieu
# http://api.openweathermap.org/data/2.5/weather?appid=f9a3e3e7e6f1ac50c785a5e9ba2273ac&q=novochernorechenskiy&units=Imperial
# Processing Record 28 of Set 16 | novochernorechenskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# check length of city data
print(len(city_data))
# Out:
# 713
